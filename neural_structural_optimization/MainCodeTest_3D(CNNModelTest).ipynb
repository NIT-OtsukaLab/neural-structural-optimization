# %%
from IPython import display
from PIL import Image
import time
import seaborn
import matplotlib.pyplot as plt
import xarray
import pandas as pd

from neural_structural_optimization import pipeline_utils
from neural_structural_optimization import problems
from neural_structural_optimization import models
from neural_structural_optimization import topo_api
from neural_structural_optimization import train

def train_all(problem, max_iterations, cnn_kwargs=None):
    args = topo_api.specified_task(problem)
    if cnn_kwargs is None:
        cnn_kwargs = {}

    model = models.CNNModel(args=args, **cnn_kwargs)
#    model = CodeTest_04_CNNModel.CNNModel(args=args, **cnn_kwargs)
    ds_cnn = train.train_lbfgs(model, max_iterations)

    dims = pd.Index(['cnn-lbfgs'], name='model')
    return xarray.concat([ds_cnn], dim=dims)

"""MBB beam with a larger grid"""
problem = problems.PROBLEMS_BY_NAME['mbb_beam_192x64x64_0.4']
max_iterations = 100

#%time ds = train_all(problem, max_iterations) %timeが機能しないため,以下の処理に変更
start = time.time()
ds = train_all(problem, max_iterations)
e_time = time.time() - start
print ("e_time:{0}".format(e_time) + "[s]")

ds.loss.transpose().to_pandas().cummin().loc[:200].plot(linewidth=2)
plt.ylim(230, 330)
plt.ylabel('Compliance (loss)')
plt.xlabel('Optimization step')
seaborn.despine()

ds.design.ffill('step').sel(step=100).plot.imshow(
    col='model', x='x', y='y', z='z', size=2, aspect=2.5, col_wrap=2,
    yincrease=False, add_colorbar=False, cmap='Greys')
plt.suptitle(problem.name, y=1.02)

ds.design.sel(step=[0, 1, 2, 5, 10, 20, 50, 100]).plot.imshow(
    row='model', col='step', x='x', y='y', z='z', size=2, aspect=0.5,
    yincrease=False, add_colorbar=False, cmap='Greys')
plt.subplots_adjust(wspace=0.1, hspace=0.05)
plt.suptitle(problem.name, y=1.02)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-415be081b3b8> in <module>
#      31 #%time ds = train_all(problem, max_iterations) %timeが機能しないため,以下の処理に変更
#      32 start = time.time()
# ---> 33 ds = train_all(problem, max_iterations)
#      34 e_time = time.time() - start
#      35 print ("e_time:{0}".format(e_time) + "[s]")
#
# <ipython-input-10-415be081b3b8> in train_all(problem, max_iterations, cnn_kwargs)
#      20     model = models.CNNModel(args=args, **cnn_kwargs)
#      21 #    model = CodeTest_04_CNNModel.CNNModel(args=args, **cnn_kwargs)
# ---> 22     ds_cnn = train.train_lbfgs(model, max_iterations)
#      23
#      24     dims = pd.Index(['cnn-lbfgs'], name='model')
#
# /users/taniguchi/reparam/neural_structural_optimization/train.py in train_lbfgs(model, max_iterations, save_intermediate_designs, init_model, **kwargs)
#     122   # rely upon the step limit instead of error tolerance for finishing.
#     123   _, _, info = scipy.optimize.fmin_l_bfgs_b(
# --> 124       value_and_grad, x0, maxfun=max_iterations, factr=1, pgtol=1e-14, **kwargs
#     125   )
#     126   logging.info(info)
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     196
#     197     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 198                            **opts)
#     199     d = {'grad': res['jac'],
#     200          'task': res['message'],
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     306     sf = _prepare_scalar_function(fun, x0, jac=jac, args=args, epsilon=eps,
#     307                                   bounds=new_bounds,
# --> 308                                   finite_diff_rel_step=finite_diff_rel_step)
#     309
#     310     func_and_grad = sf.fun_and_grad
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/scipy/optimize/optimize.py in _prepare_scalar_function(fun, x0, jac, args, bounds, epsilon, finite_diff_rel_step, hess)
#     260     # calculation reduces overall function evaluations.
#     261     sf = ScalarFunction(fun, x0, args, grad, hess,
# --> 262                         finite_diff_rel_step, bounds, epsilon=epsilon)
#     263
#     264     return sf
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/scipy/optimize/_differentiable_functions.py in __init__(self, fun, x0, args, grad, hess, finite_diff_rel_step, finite_diff_bounds, epsilon)
#      74
#      75         self._update_fun_impl = update_fun
# ---> 76         self._update_fun()
#      77
#      78         # Gradient evaluation
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/scipy/optimize/_differentiable_functions.py in _update_fun(self)
#     164     def _update_fun(self):
#     165         if not self.f_updated:
# --> 166             self._update_fun_impl()
#     167             self.f_updated = True
#     168
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/scipy/optimize/_differentiable_functions.py in update_fun()
#      71
#      72         def update_fun():
# ---> 73             self.f = fun_wrapped(self.x)
#      74
#      75         self._update_fun_impl = update_fun
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/scipy/optimize/_differentiable_functions.py in fun_wrapped(x)
#      68         def fun_wrapped(x):
#      69             self.nfev += 1
# ---> 70             return fun(x, *args)
#      71
#      72         def update_fun():
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/scipy/optimize/optimize.py in __call__(self, x, *args)
#      72     def __call__(self, x, *args):
#      73         """ returns the the function value """
# ---> 74         self._compute_if_needed(x, *args)
#      75         return self._value
#      76
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/scipy/optimize/optimize.py in _compute_if_needed(self, x, *args)
#      66         if not np.all(x == self.x) or self._value is None or self.jac is None:
#      67             self.x = np.asarray(x).copy()
# ---> 68             fg = self.fun(x, *args)
#      69             self.jac = fg[1]
#      70             self._value = fg[0]
#
# /users/taniguchi/reparam/neural_structural_optimization/train.py in value_and_grad(x)
#     113       t.watch(tvars)
#     114       logits = model(None)
# --> 115       loss = model.loss(logits)
#     116     grads = t.gradient(loss, tvars)
#     117     frames.append(logits.numpy().copy())
#
# /users/taniguchi/reparam/neural_structural_optimization/models.py in loss(self, logits)
#      63     logits = 0.0 + tf.cast(logits, tf.float64)
#      64     f = lambda x: batched_topo_loss(x, [self.env])
# ---> 65     losses = convert_autograd_to_tensorflow(f)(logits)
#      66     return tf.reduce_mean(losses)
#      67
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/tensorflow/python/ops/custom_gradient.py in __call__(self, *a, **k)
#     262
#     263   def __call__(self, *a, **k):
# --> 264     return self._d(self._f, a, k)
#     265
#     266
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/tensorflow/python/ops/custom_gradient.py in decorated(wrapped, args, kwargs)
#     216
#     217     if context.executing_eagerly():
# --> 218       return _eager_mode_decorator(wrapped, args, kwargs)
#     219     else:
#     220       return _graph_mode_decorator(wrapped, args, kwargs)
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/tensorflow/python/ops/custom_gradient.py in _eager_mode_decorator(f, args, kwargs)
#     410   """Implement custom gradient decorator for eager mode."""
#     411   with tape_lib.VariableWatcher() as variable_watcher:
# --> 412     result, grad_fn = f(*args, **kwargs)
#     413   args = nest.flatten(args)
#     414   all_inputs = list(args) + list(kwargs.values())
#
# /users/taniguchi/reparam/neural_structural_optimization/models.py in wrapper(x)
#      38   @tf.custom_gradient
#      39   def wrapper(x):
# ---> 40     vjp, ans = autograd.core.make_vjp(func, x.numpy())
#      41     return ans, vjp
#      42   return wrapper
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/autograd/core.py in make_vjp(fun, x)
#       8 def make_vjp(fun, x):
#       9     start_node = VJPNode.new_root()
# ---> 10     end_value, end_node =  trace(start_node, fun, x)
#      11     if end_node is None:
#      12         def vjp(g): return vspace(x).zeros()
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/autograd/tracer.py in trace(start_node, fun, x)
#       8     with trace_stack.new_trace() as t:
#       9         start_box = new_box(x, t, start_node)
# ---> 10         end_box = fun(start_box)
#      11         if isbox(end_box) and end_box._trace == start_box._trace:
#      12             return end_box._value, end_box._node
#
# /users/taniguchi/reparam/neural_structural_optimization/models.py in <lambda>(x)
#      62     # add 0.0 to work-around bug in grad of tf.cast on NumPy arrays
#      63     logits = 0.0 + tf.cast(logits, tf.float64)
# ---> 64     f = lambda x: batched_topo_loss(x, [self.env])
#      65     losses = convert_autograd_to_tensorflow(f)(logits)
#      66     return tf.reduce_mean(losses)
#
# /users/taniguchi/reparam/neural_structural_optimization/models.py in batched_topo_loss(params, envs)
#      31 def batched_topo_loss(params, envs):
#      32   losses = [env.objective(params[i], volume_contraint=True)
# ---> 33             for i, env in enumerate(envs)]
#      34   return np.stack(losses)
#      35
#
# /users/taniguchi/reparam/neural_structural_optimization/models.py in <listcomp>(.0)
#      31 def batched_topo_loss(params, envs):
#      32   losses = [env.objective(params[i], volume_contraint=True)
# ---> 33             for i, env in enumerate(envs)]
#      34   return np.stack(losses)
#      35
#
# /users/taniguchi/reparam/neural_structural_optimization/topo_api.py in objective(self, params, volume_contraint)
#      68     return topo_physics.objective(
#      69         self.reshape(params), self.ke, self.args,
# ---> 70         volume_contraint=volume_contraint,
#      71     )
#      72
#
# /users/taniguchi/reparam/neural_structural_optimization/topo_physics.py in objective(x, ke, args, volume_contraint, cone_filter)
#     304   """Objective function (compliance) for topology optimization."""
#     305   kwargs = dict(penal=args['penal'], e_min=args['young_min'], e_0=args['young'])
# --> 306   x_phys = physical_density(x, args, volume_contraint=volume_contraint, cone_filter=cone_filter)
#     307   forces = calculate_forces(x_phys, args)
#     308   u = displace(x_phys, ke, forces, args['freedofs'], args['fixdofs'], **kwargs)
#
# /users/taniguchi/reparam/neural_structural_optimization/topo_physics.py in physical_density(x, args, volume_contraint, cone_filter)
#      84     x = x * args['mask']
#      85   if cone_filter:
# ---> 86     x = autograd_lib.cone_filter(x, args['filter_width'], args['mask'])
#      87   return x
#      88
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/autograd/tracer.py in f_wrapped(*args, **kwargs)
#      42             parents = tuple(box._node for _     , box in boxed_args)
#      43             argnums = tuple(argnum    for argnum, _   in boxed_args)
# ---> 44             ans = f_wrapped(*argvals, **kwargs)
#      45             node = node_constructor(ans, f_wrapped, argvals, kwargs, argnums, parents)
#      46             return new_box(ans, trace, node)
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/autograd/tracer.py in f_wrapped(*args, **kwargs)
#      46             return new_box(ans, trace, node)
#      47         else:
# ---> 48             return f_raw(*args, **kwargs)
#      49     f_wrapped.fun = f_raw
#      50     f_wrapped._is_autograd_primitive = True
#
# /users/taniguchi/reparam/neural_structural_optimization/autograd_lib.py in cone_filter(inputs, radius, mask, transpose)
#     147   raw_filters = _cone_filter_matrix(nx, ny, nz, radius, mask).tocsr()
#     148   weights = 1 / raw_filters.sum(axis=0).squeeze()
# --> 149   diag_weights = scipy.sparse.spdiags(weights, 0, nx*ny, ny*nz, nz*nx),
#     150   return (diag_weights @ raw_filters).tocsr()
#     151
#
# /users/taniguchi/reparam/neural_structural_optimization/caching.py in wrapper(*args, **kwargs)
#      52       kwargs = {k: _WrappedArray(v) if isinstance(v, np.ndarray) else v
#      53                 for k, v in kwargs.items()}
# ---> 54       return cached_func(*args, **kwargs)
#      55
#      56     return wrapper
#
# /users/taniguchi/reparam/neural_structural_optimization/caching.py in cached_func(*args, **kwargs)
#      44       kwargs = {k: v.value if isinstance(v, _WrappedArray) else v
#      45                 for k, v in kwargs.items()}
# ---> 46       return func(*args, **kwargs)
#      47
#      48     @functools.wraps(func)
#
# /users/taniguchi/reparam/neural_structural_optimization/autograd_lib.py in normalized_cone_filter_matrix(nx, ny, nz, radius, mask)
#     137   data = np.concatenate(values)
#     138   i = np.concatenate(rows)
# --> 139   j = np.concatenate(cols)
#     140   return scipy.sparse.coo_matrix((data, (i, j)), (nelx * nely * nelz,) * 2)
#     141   #return scipy.sparse.coo_matrix((data, (i, j)), (nelx * nely,) * 2)
#
# /users/taniguchi/reparam/neural_structural_optimization/autograd_lib.py in _cone_filter_matrix(nelx, nely, nelz, radius, mask)
#      89       for dz in range(-r_bound, r_bound+1):
#      90 """
# ---> 91   weight = np.maximum(0, radius - np.sqrt(dx**2 + dy**2 + dz**2))
#      92   shape = np.ones((dz, dy, dx))
#      93
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/scipy/ndimage/filters.py in correlate(input, weights, output, mode, cval, origin)
#     694     """
#     695     return _correlate_or_convolve(input, weights, output, mode, cval,
# --> 696                                   origin, False)
#     697
#     698
#
# ~/.local/share/virtualenvs/reparam-cfaYz6qU/lib/python3.6/site-packages/scipy/ndimage/filters.py in _correlate_or_convolve(input, weights, output, mode, cval, origin, convolution)
#     603     wshape = [ii for ii in weights.shape if ii > 0]
#     604     if len(wshape) != input.ndim:
# --> 605         raise RuntimeError('filter weights array has incorrect shape.')
#     606     if convolution:
#     607         weights = weights[tuple([slice(None, None, -1)] * weights.ndim)]
#
# RuntimeError: filter weights array has incorrect shape.
